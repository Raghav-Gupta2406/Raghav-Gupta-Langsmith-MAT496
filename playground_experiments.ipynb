# %% [markdown]
# # Run Experiments in Playground

# %% [markdown]
# ### Setup

# %%
# You can set them inline
import os
os.environ["LANGSMITH_API_KEY"] = ""

# %%
# Or you can use a .env file
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Create a Dataset

# %% [markdown]
# Let's create a toy example dataset to run experiments over for a prompt

# %%
from langsmith import Client

example_inputs = [
    ("What is the capital of France?", "The capital of France is Paris"),
    ("What is the capital of Japan?", "The capital of Japan is Tokyo"),
    ("What is the capital of Egypt?", "The capital of Egypt is Cairo"),
]

client = Client()
dataset_name = "Sample Questions 3"

dataset = client.create_dataset(
    dataset_name=dataset_name, 
    description="Sample questions about color",
)

inputs = [{"question": question} for question, answer in example_inputs]
outputs = [{"output": answer} for question, answer in example_inputs]

client.create_examples(
    inputs=inputs,
    outputs=outputs,
    dataset_id=dataset.id,
)

print("Dataset created successfully! Check your LangSmith dashboard.")
# Out:
# Dataset created successfully! Check your LangSmith dashboard.

# %% [markdown]
# ![MODULE 3 LESSON 1.png](<attachment:MODULE 3 LESSON 1.png>)

# %% [markdown]
# ![image.png](attachment:image.png)
